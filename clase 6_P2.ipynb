# %%
import pandas as pd

# %%
pokemon="C:\\Users\\User\\Pokemon.csv" 
pokemon_df=pd.read_csv(pokemon)
pokemon_df
# Out:
#      Num        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# ...

# %%
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Num        151 non-null    int64
#  1   Name       151 non-null    object
#  2   Type 1     151 non-null    object
#  3   Type 2     67 non-null     object
#  4   Total      151 non-null    int64
#  5   HP         151 non-null    int64
#  6   Attack     151 non-null    int64
#  7   Defense    151 non-null    int64
#  8   Sp. Atk    151 non-null    int64
#  9   Sp. Def    151 non-null    int64
#  10  Speed      151 non-null    int64
#  11  Stage      151 non-null    int64
#  12  Legendary  151 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 14.4+ KB

# %%
bitcoin="C:\\Users\\User\\data\\coin_Bitcoin.csv"
bitcoin_df=pd.read_csv(bitcoin, index_col=0)

# %%
bitcoin_df
# Out:
#          Name Symbol                 Date          High           Low  \
# SNo
# 1     Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 2     Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 3     Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 4     Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 5     Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...       ...    ...                  ...           ...           ...
# 2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# SNo
# ...

# %%
bitcoin_df["High"].plot()
# Out:
# <Axes: xlabel='SNo'>

# %%
#set index, si se corre más de una vez, va ha marcar error, pero con head vuelve al anerior, es temporal 
#no es una modificación permanente
#bitcoin_df.set_index("Date", inplace=True) es para que sea permanente
bitcoin_df.set_index("Date", inplace=True)

# %%
#bitcoin_df.set_index("Date", inplace=True) es para que sea permanente
bitcoin_df["High"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#otro parametro es rot rot45
bitcoin_df["High"].plot(rot=45)
# Out:
# <Axes: xlabel='Date'>

# %%
happy="C:\\Users\\User\\data\\world-happiness-report-2021.csv" 
happy_df=pd.read_csv(happy)
happy_df
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
happy_df.set_index("Country name", inplace=True)["Healthy life expectancy"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 happy_df.set_index("Country name", inplace=True)["Healthy life expectancy"]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
happy_df
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
happy_df["Healthy life expectancy"].nlargest(10).plot()
# Out:
# <Axes: xlabel='Country name'>

# %%
happy_df["Healthy life expectancy"].nlargest(10)
# Out:
# Country name
# Singapore                    76.953
# Hong Kong S.A.R. of China    76.820
# Japan                        75.100
# Spain                        74.700
# Switzerland                  74.400
# France                       74.000
# Australia                    73.900
# South Korea                  73.900
# Cyprus                       73.898
# North Cyprus                 73.898
# Name: Healthy life expectancy, dtype: float64

# %%
happy_df["Healthy life expectancy"].nlargest(10).plot(kind="barh")
# Out:
# <Axes: ylabel='Country name'>

# %%
happy_df["Perceptions of corruption"].nsmallest(10).plot(kind="barh")
#Perceptions of corruption
# Out:
# <Axes: ylabel='Country name'>

# %%
happy_df["Perceptions of corruption"].nlargest(10).plot(kind="barh")
# Out:
# <Axes: ylabel='Country name'>

# %%
happy_df.columns
# Out:
# Index(['Regional indicator', 'Ladder score', 'Standard error of ladder score',
#        'upperwhisker', 'lowerwhisker', 'Logged GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
#sort_values(): metodo que nos permite ordenar valoneres tanto numeros como no, 
#del más chico al más grande o se le puede especificar
happy_df.sort_values('Healthy life expectancy', ascending=False) #así es de mayor a menor
# Out:
#                            Regional indicator  Ladder score  \
# Country name
# Singapore                      Southeast Asia         6.377
# Hong Kong S.A.R. of China           East Asia         5.477
# Japan                               East Asia         5.940
# Spain                          Western Europe         6.491
# Switzerland                    Western Europe         7.571
# ...                                       ...           ...
# Swaziland                  Sub-Saharan Africa         4.308
# Ivory Coast                Sub-Saharan Africa         5.306
# Nigeria                    Sub-Saharan Africa         4.759
# Lesotho                    Sub-Saharan Africa         3.512
# Chad                       Sub-Saharan Africa         4.355
#
#                            Standard error of ladder score  upperwhisker  \
# Country name
# Singapore                                           0.043         6.460
# ...

# %%
houses="C:\\Users\\User\\data\\kc_house_data.csv"
houses_df= pd.read_csv(houses)
houses_df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses_df.sort_values("bedrooms")
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 9773   3374500520  20150429T000000   355000.0         0       0.00
# 6994   2954400190  20140624T000000  1295650.0         0       0.00
# 9854   7849202190  20141223T000000   235000.0         0       0.00
# 19452  3980300371  20140926T000000   142000.0         0       0.00
# 14423  9543000205  20150413T000000   139950.0         0       0.00
# ...           ...              ...        ...       ...        ...
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 15870  2402100895  20140625T000000   640000.0        33       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 9773          2460      8049     2.0           0     0  ...      8
# ...

# %%
houses_df.sort_values(["bedrooms", "bathrooms"], ascending=False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# ...           ...              ...        ...       ...        ...
# 6994   2954400190  20140624T000000  1295650.0         0       0.00
# 9773   3374500520  20150429T000000   355000.0         0       0.00
# 9854   7849202190  20141223T000000   235000.0         0       0.00
# 14423  9543000205  20150413T000000   139950.0         0       0.00
# 19452  3980300371  20140926T000000   142000.0         0       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# ...

# %%
houses_df.sort_values(["bedrooms", "bathrooms"], ascending=False, inplace=True)

# %%
houses_df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# ...           ...              ...        ...       ...        ...
# 6994   2954400190  20140624T000000  1295650.0         0       0.00
# 9773   3374500520  20150429T000000   355000.0         0       0.00
# 9854   7849202190  20141223T000000   235000.0         0       0.00
# 14423  9543000205  20150413T000000   139950.0         0       0.00
# 19452  3980300371  20140926T000000   142000.0         0       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# ...

# %%
#columnas de texto
#recordar funciones
titanic= "C:\\Users\\User\\data\\titanic.csv"
titanic_df= pd.read_csv(titanic) 
titanic_df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic_df.sort_values("name")
#el orden alfabético primero ABCD....(mayusculas), luego abcd....(minúsculas)
# Out:
#       pclass  survived                                           name     sex  \
# 600        3         0                            Abbing, Mr. Anthony    male
# 601        3         0                  Abbott, Master. Eugene Joseph    male
# 602        3         0                    Abbott, Mr. Rossmore Edward    male
# 603        3         1               Abbott, Mrs. Stanton (Rosa Hunt)  female
# 604        3         1                    Abelseth, Miss. Karen Marie  female
# ...      ...       ...                                            ...     ...
# 392        2         1  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female
# 1262       3         0            van Billiard, Master. James William    male
# 1263       3         0              van Billiard, Master. Walter John    male
# 1264       3         0                van Billiard, Mr. Austin Blyler    male
# 1268       3         0                    van Melkebeke, Mr. Philemon    male
#
# ...

# %%
titanic_df.sort_values("name", key=#funcioón shida) #podemos incluir multiples columnas en sort_values
                       #ascending

# %%
#lambda functions, se pueden pasar como argumentos, función anónima
def mifuncion(a):
    x = a+10
    return x

# %%
mifuncion(10)
# Out:
# 20

# %%
titanic_df.sort_values("name", key=lambda col:col.str.lower()) #homogenizar todas a minusculas para odenar
#odenar por nombres
# Out:
#       pclass  survived                              name     sex   age  sibsp  \
# 600        3         0               Abbing, Mr. Anthony    male    42      0
# 601        3         0     Abbott, Master. Eugene Joseph    male    13      0
# 602        3         0       Abbott, Mr. Rossmore Edward    male    16      1
# 603        3         1  Abbott, Mrs. Stanton (Rosa Hunt)  female    35      1
# 604        3         1       Abelseth, Miss. Karen Marie  female    16      0
# ...      ...       ...                               ...     ...   ...    ...
# 1304       3         0              Zabour, Miss. Hileni  female  14.5      1
# 1305       3         0             Zabour, Miss. Thamine  female     ?      1
# 1306       3         0         Zakarian, Mr. Mapriededer    male  26.5      0
# 1307       3         0               Zakarian, Mr. Ortin    male    27      0
# 1308       3         0                Zimmerman, Mr. Leo    male    29      0
#
# ...

# %%
#sort_index(ascending=Boolean)
happy_df.sort_index(inplace=True)

# %%
houses_df.sort_values("bathrooms")
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 19452  3980300371  20140926T000000   142000.0         0       0.00
# 9854   7849202190  20141223T000000   235000.0         0       0.00
# 9773   3374500520  20150429T000000   355000.0         0       0.00
# 6994   2954400190  20140624T000000  1295650.0         0       0.00
# 3119   3918400017  20150205T000000   380000.0         0       0.00
# ...           ...              ...        ...       ...        ...
# 8092   1924059029  20140617T000000  4668000.0         5       6.75
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 12777  1225069038  20140505T000000  2280000.0         7       8.00
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 19452          290     20875     1.0           0     0  ...      1
# ...

# %%
houses_df
# Out:
#                   id             date      price  bathrooms  sqft_living  \
# bedrooms
# 33        2402100895  20140625T000000   640000.0       1.75         1620
# 11        1773100755  20140821T000000   520000.0       3.00         3000
# 10         627300145  20140814T000000  1148000.0       5.25         4590
# 10        8812401450  20141229T000000   660000.0       3.00         2920
# 10        5566100170  20141029T000000   650000.0       2.00         3610
# ...              ...              ...        ...        ...          ...
# 0         2954400190  20140624T000000  1295650.0       0.00         4810
# 0         3374500520  20150429T000000   355000.0       0.00         2460
# 0         7849202190  20141223T000000   235000.0       0.00         1470
# 0         9543000205  20150413T000000   139950.0       0.00          844
# 0         3980300371  20140926T000000   142000.0       0.00          290
#
#           sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# ...

# %%
houses_df.
# Out:
#                   id             date      price  bathrooms  sqft_living  \
# bedrooms
# 33        2402100895  20140625T000000   640000.0       1.75         1620
# 11        1773100755  20140821T000000   520000.0       3.00         3000
# 10         627300145  20140814T000000  1148000.0       5.25         4590
# 10        8812401450  20141229T000000   660000.0       3.00         2920
# 10        5566100170  20141029T000000   650000.0       2.00         3610
#
#           sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# bedrooms
# 33            6000     1.0           0     0          5      7        1040
# 11            4960     2.0           0     0          3      7        2400
# 10           10920     1.0           0     2          3      9        2500
# 10            3745     2.0           0     0          4      7        1860
# 10           11914     2.0           0     0          4      7        3010
#
# ...

# %%
houses_df["bathrooms"].plot(kind="bar")
# Out:
# <Axes: xlabel='bedrooms'>
# Error in callback <function flush_figures at 0x0000023F698B8360> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\matplotlib_inline\backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~\anaconda3\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
# ...

# %%
titanic_df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

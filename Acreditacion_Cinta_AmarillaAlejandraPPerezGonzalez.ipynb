# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Primera Evaluación. Duración máxima de la prueba (1 Hora)
# ### Temas: Aritmetica Básica, Asignación de Variables, Indexing(Sub)[::], Print y Formatos, Listas( ), Diccionarios{:} , Tuplas[] y Sets(), Booleans(T/F)
# Instrucciones:
#
# ** Lee con atención y completa y/o responde las siguientes preguntas/ejercicios **

# %% [markdown]
# # 1. Escribe una descripción de los siguientes tipos de variables. Puedes editar la celda dando doble click en ella.

# %% [markdown]
# Da doble click sobre esta celda para responder!
#
# Numbers: Variables que contienen caracteres numericos (pueden ser integers, flotantes)
#
# Strings: Variable que es una secuencias de caracteres tipo texto
#
# Lists: Secuencia de caracteres numericos o strings que se guarda en una lista. Las variables tipo listas pueden editarse, y pueden colocarse en la lista diferentes tipos de variables.
#
# Tuples: Tipo de variable parecido a las listas, son secuencias de caracteres numericos o strings pero no son editables
#
# Dictionaries: variables que almacenan una pareja de terminos en una llave, donde hay un valor y un significado. Se puede acceder a un significado mediante una llave.

# %% [markdown]
# # 2. Escribe una operación aritmética que utilice la multiplicación, la división, la suma, los exponentes y la resta para que el resultado sea 5124.23.
#
# TIP: Empieza por el resultado y ve para atrás

# %%
((((10245.62665*2))/2**2) + 1) - -0.4166749999994863 #lol i tried hard
# Out:
# 5124.23

# %% [markdown]
# # 3. Cuál es el resultado de las siguientes operaciones sin escribir código ni usar calculadora. (Da doble click sobre esta celda para escribir tu resputesta)
#
#     A)  4 * (6 + 5) = 44
#
#     B) 4 * 6 + 5 = 29
#
#     C) 4 + 6 * 5 = 34

# %% [markdown]
# # 4. Escribe el Código correspondiente para resolver las ecuaciones anteriores y corre la celda para obtener el resultado. No puedes modificar tus respuestas anteriores.

# %%
4 * (6 + 5)
# Out:
# 44

# %%
(4 * 6) + 5
# Out:
# 29

# %%
4 + (6 * 5)
# Out:
# 34

# %% [markdown]
# # 5. Cuál es el "type" del resultado de la siguiente operación?
# 3 + 1.5 + 4

# %% [markdown]
# #doble click aquí para escribir tu respuesta
#
# es un float, porque tiene decimales

# %% [markdown]
# # 6. Cómo obtengo el cuadrado de un número? y Cómo obtengo su raiz cuadrada?

# %%
# Raiz:
7**(1/2)  #usando una potencia a la mitad lol
# Out:
# 2.6457513110645907

# %%
# Cuadrado:
4**2
# Out:
# 16

# %% [markdown]
# # 7. Dada la cadena siguente, escribe el código para imprimir la letra "a"

# %%
s = 'pizza'

s[-1]
# Out:
# 'a'

# %% [markdown]
# # 8. Usando slicing, regresa la siguiente cadena pero al reves:

# %%
s ='ravioles'
s[-1::-1]
# Out:
# 'seloivar'

# %% [markdown]
# # 9. Escribe dos formas diferentes de obtener la letra "o" de la sigiente cadena

# %%
s ='Hola'
# Imprime la letra 'o'

# Método 1:
s[1]
# Out:
# 'o'

# %%
# Método 2:
s[-3]
# Out:
# 'o'

# %% [markdown]
# # Listas

# %% [markdown]
# # 10. Contruye la siguiente lista de dos formas diferentes: [0,0,0].

# %%
# Método 1:

lista = [0, 0, 0]
# Out:
# list

# %%
# Método 2:

lista = [0]
lista.append(0)
lista.append(0)

print(lista)
# Out:
# [0, 0, 0]

# %% [markdown]
# # 11. Cambia la palabra pizza por ravioles sin modificar el resto de la lista:
# (No se vale crear una nueva lista)

# %%
lista = [1,2,[3,4,'pizza']]
lista[2][2] = 'ravioles'
print(lista)
# Out:
# [1, 2, [3, 4, 'ravioles']]

# %% [markdown]
# # 12. Ordena la siguente lista:

# %%
lista = [5,3,4,6,1]
lista.sort()
print(lista)
# Out:
# [1, 3, 4, 5, 6]

# %% [markdown]
# # Diccionarios / Dictionaries

# %% [markdown]
# # 13. Utilizando llaves regresa la palabra solicitada de los siguientes diccionarios:

# %%
d = {'pasta':'pizza'}
# Regresa pizza
d['pasta']
# Out:
# 'pizza'

# %%
d = {'comidas':{'pastas':'ravioles'}}
# Regresa ravioles'
d['comidas']['pastas']
# Out:
# 'ravioles'

# %%
# Matrushkas
d = {'m1':[{'m2':['m3',['m4']]}]}

#Regresa m4

d['m1'][0]['m2'][1]
# Out:
# ['m4']

# %%
# Matrushkaas absurdas!
#Regresa m4

d = {'m1':[1,2,{'m2':['m3',{'nomanches':[1,2,['m4']]}]}]}

d['m1'][2]['m2'][1]['nomanches'][2]
# Out:
# ['m4']

# %% [markdown]
# # 14. Puedo ordenar un diccionario? (si/no)

# %% [markdown]
# #doble click aquí para escribir tu respuesta
#
# Creeeeo que no (not sure pero mi respuesta es no)

# %% [markdown]
# # Tuplas o Tuples

# %% [markdown]
# # 15. ¿Cuál es la diferencia principal entre una tupla y una lista?

# %% [markdown]
# #doble click aquí para escribir tu respuesta
#
# Las tuplas no se pueden editar, las listas si. Las tuplas usan los () y las listas usan [].

# %% [markdown]
# # 16. Crea una tupla con las letras: A,C,G,T

# %%
tupla = ('A', 'C', 'G', 'T')
print(tupla)
# Out:
# ('A', 'C', 'G', 'T')

# %% [markdown]
# # Sets

# %% [markdown]
# # 17. ¿Qué es un set?

# %% [markdown]
# #doble click aquí para escribir tu respuesta
#
# Es una lista de las variables unicas que hay en una lista o tupla

# %% [markdown]
# # 18. Regresa los valores unicos de la lista siguiente utilizando sets:

# %%
list5 = [1,2,2,33,4,4,11,22,3,3,2]
set(list5)
# Out:
# {1, 2, 3, 4, 11, 22, 33}

# %% [markdown]
# # Booleans

# %% [markdown]
# # 19. Escribe el resultado de las siguiente comparaciones (True/False)

# %% [markdown]
# 2 > 3

# %%
2 > 3
# Out:
# False

# %% [markdown]
# #doble click aquí para escribir tu respuesta
#
# False

# %% [markdown]
# 3 <= 2

# %%
3 <= 2
# Out:
# False

# %% [markdown]
# #doble click aquí para escribir tu respuesta
#
# False

# %% [markdown]
# 3 == 2.0

# %%
3 == 2.0
# Out:
# False

# %% [markdown]
# #doble click aquí para escribir tu respuesta
#
# False

# %% [markdown]
# 3.0 == 3

# %%
3.0 == 3
# Out:
# True

# %% [markdown]
# #doble click aquí para escribir tu respuesta

# %% [markdown]
# 4**0.5 != 2

# %%
4**0.5 != 2
# Out:
# False

# %% [markdown]
# #doble click aquí para escribir tu respuesta

# %% [markdown]
# # Observa las siguientes listas acopladas
#
# listaA = [1,2,[3,4]]
#
# listaB = [1,2,{'k1':4}]
#
#
# # 20 . Dadas las listas anteriores, la siguiente comparación da True o False?
#
# listaA[2][0] >= listaB[2]['k1']

# %%
listaA = [1,2,[3,4]]
comp1= listaA[2][0]

print(comp1)

listaB = [1,2,{'k1':4}]
comp2 = listaB[2]['k1']

print(comp2)

'La compraacion es ' + str(comp1 >= comp2)
# Out:
# 3
# 4
# 'La compraacion es False'

# %% [markdown]
# #doble click aquí para escribir tu respuesta
#
# Falso

# %% [markdown]
# ### Gran Esfuerzo! Has terminado la primera evaluación del curso!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Extra:
# # Escribe honestamente que tan dificil te pareció el examen.
#
# Puedes usar una escala del 1 al 10 o escribir con tus propias palabras.
# Escala (1-10) :1-Pan comido, 10-Imposible

# %% [markdown]
# #doble click aquí para escribir tu respuesta
#
# 5, no estuvo tan facil

# %%
import pandas as pd

# %%
titanic =  pd.read_csv("/home/tiamat/Desktop/Python_Dojo/data/titanic.csv")

# %%
titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %% [markdown]
# # FILTRADO DE DATOS

# %% [markdown]
# Ya sabemos encontrar por locacion o valor
# Pero como podemos obtener por ejemplo todas las personas mayores a 20 anos
# O las personas que sobrevivieron y son mujeres
# Todas las personas de 1ra clase que sobreviieron vs las personas de 3ra clase que sobrevivieron
#
# RECORDATORIO
#
# ==  identico
#
# => mayor o igual
#
# <= menor o igual
#
# != diferente
#
# <
#
# '>'

# %%
titanic.sex == 'female'

#Este tipo de serie que tiene verdaderos y falsos, se llaman mascaras
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1304     True
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: sex, Length: 1309, dtype: bool

# %%
titanic[titanic.sex == 'female']
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
mascara = titanic.sex == 'female'
titanic[mascara]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
#Esto primariamente no va a funcionar... porque
#el error dice ValueError: Item wrong length 6 instead of 1309.

coladera = [True, True, True, False,  False, True]

titanic[coladera]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_30777/1119138859.py in ?()
#       1 #Esto primariamente no va a funcionar
#       2
#       3 coladera = [True, True, True, False,  False, True]
#       4
# ----> 5 titanic[coladera]
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, key)
#    4089             return self.where(key)
#    4090
#    4091         # Do we have a (boolean) 1d indexer?
#    4092         if com.is_bool_indexer(key):
# -> 4093             return self._getitem_bool_array(key)
#    4094
#    4095         # We are left with two options: a single key, and a collection of keys,
#    4096         # We interpret tuples as collections only for non-MultiIndex
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, key)
#    4139                 UserWarning,
# ...

# %%
#Podemos darle un subset de lo que queremos filtrar

coladera = [True, True, True, False,  False, True]

titanic.head(6)[coladera]
# Out:
#    pclass  survived                            name     sex     age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female      29      0
# 1       1         1  Allison, Master. Hudson Trevor    male  0.9167      1
# 2       1         0    Allison, Miss. Helen Loraine  female       2      1
# 5       1         1             Anderson, Mr. Harry    male      48      0
#
#    parch  ticket      fare    cabin embarked boat body  \
# 0      0   24160  211.3375       B5        S    2    ?
# 1      2  113781    151.55  C22 C26        S   11    ?
# 2      2  113781    151.55  C22 C26        S    ?    ?
# 5      0   19952     26.55      E12        S    3    ?
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 5                     New York, NY

# %% [markdown]
# # RETO

# %% [markdown]
# 1) Dame la lista de pasajeros del titanic que tienen mas de 21 anios

# %%
titanic[titanic.age > '21']
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# ...      ...       ...                                              ...
# 1303       3         0                            Yousseff, Mr. Gerious
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# 2) Dame la lista de todos los pasajeros de la clase 2 y 3 (No clase 1)(pclass)

# %%
titanic[titanic.pclass != 1]
# Out:
#       pclass  survived                                   name     sex   age  \
# 323        2         0                    Abelson, Mr. Samuel    male    30
# 324        2         1  Abelson, Mrs. Samuel (Hannah Wizosky)  female    28
# 325        2         0         Aldworth, Mr. Charles Augustus    male    30
# 326        2         0             Andrew, Mr. Edgardo Samuel    male    18
# 327        2         0               Andrew, Mr. Frank Thomas    male    25
# ...      ...       ...                                    ...     ...   ...
# 1304       3         0                   Zabour, Miss. Hileni  female  14.5
# 1305       3         0                  Zabour, Miss. Thamine  female     ?
# 1306       3         0              Zakarian, Mr. Mapriededer    male  26.5
# 1307       3         0                    Zakarian, Mr. Ortin    male    27
# 1308       3         0                     Zimmerman, Mr. Leo    male    29
#
# ...

# %% [markdown]
# 3. Dame la lista de casas con mas de 10 camas (bedrooms)

# %%
houses = pd.read_csv("/home/tiamat/Desktop/Python_Dojo/data/kc_house_data.csv")

# %%
houses[houses.bedrooms > 10]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000  520000.0        11       3.00
# 15870  2402100895  20140625T000000  640000.0        33       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 15870         1620      6000     1.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 8757         2400            600      1918          1999    98106  47.5560
# 15870        1040            580      1947             0    98103  47.6878
#
#           long  sqft_living15  sqft_lot15
# 8757  -122.363           1420        4960
# 15870 -122.331           1330        4700
#
# [2 rows x 21 columns]

# %% [markdown]
# # between(min, max)

# %%
houses.price.describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
#Es para ver datos dentro de mi rango
houses.price.between(321950, 450000)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608     True
# 21609     True
# 21610     True
# 21611     True
# 21612     True
# Name: price, Length: 21613, dtype: bool

# %%
houses[houses.price.between(321950, 450000)]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 9      3793500160  20150312T000000  323000.0         3       2.50
# 13     6054650070  20141007T000000  400000.0         3       1.75
# 16     1875500060  20140731T000000  395000.0         3       2.00
# 20     6300500875  20140514T000000  385000.0         4       1.75
# 24     3814700200  20141120T000000  329000.0         3       2.25
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 9             1890      6560     2.0           0     0  ...      7
# ...

# %%
#Podriamos hacerlo de esta manera

min_house = houses.price > 321960
max_house = houses.price < 450000

houses[min_house & max_house]

#Es diferente el AND de los condicionales ifelse  que es and
#tambien puede ser &
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 9      3793500160  20150312T000000  323000.0         3       2.50
# 13     6054650070  20141007T000000  400000.0         3       1.75
# 16     1875500060  20140731T000000  395000.0         3       2.00
# 20     6300500875  20140514T000000  385000.0         4       1.75
# 24     3814700200  20141120T000000  329000.0         3       2.25
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 9             1890      6560     2.0           0     0  ...      7
# ...

# %%
110 & 110
# Out:
# 110

# %%
101010 & 110111
# Out:
# 100882

# %%
101010|110111
# Out:
# 110239

# %%
houses[(houses.price >= 22000) & (houses.price <= 400000)]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 6      1321400060  20140627T000000  257500.0         3       2.25
# 7      2008000270  20150115T000000  291850.0         3       1.50
# 8      2414600126  20150415T000000  229500.0         3       1.00
# ...           ...              ...       ...       ...        ...
# 21602   844000965  20140626T000000  224000.0         3       1.75
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# # RETO

# %%
#Dame el DF con las casas con mas de 2 recamaras y al menos dos banos

# %%
houses[(houses.bedrooms > 2) & (houses.bathrooms >= 2)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# ...           ...              ...        ...       ...        ...
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21611   291310100  20150116T000000   400000.0         3       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1             2570      7242     2.0           0     0  ...      7
# ...

# %% [markdown]
# ![image.png](attachment:f58a0a60-21a8-45d8-ba23-76916d84938f.png)

# %% [markdown]
# # Instrucciones:
#
# ## ** Lee con atención y completa y/o responde las siguientes preguntas/ejercicios **

# %% [markdown]
# # 1. Convierte las siguientes celdas a markdown, y responde las siguientes preguntas de forma escrita

# %% [markdown]
# ### ¿Qué es un dataset?

# %%
Un dataset es un formato tipo filas y columnas que contiene una coleccion o serie de datos sobre observaciones concretas (variables), usualmente representado en formato tabular

# %% [markdown]
# ### ¿Qué es Pandas?

# %%
Pandas es un paquete de herramientas para el analisis de datos de Python

# %% [markdown]
# ### ¿Qué es un Dataframe?

# %%
Un dataframe es un tipo de formato tabular para la representacion de variables

# %% [markdown]
# ### ¿Qué es una Serie?

# %%
Una serie es una columna de un dataframe, o un vector de una sola dimension

# %% [markdown]
# ### ¿Cuál es la diferencia entre una función y un método?

# %% [markdown]
# Una funcion es una instruccion de codigo que lleva a cabo una tarea especifica
#
# Un metodo x.metodo() describe a un objeto

# %% [markdown]
# # Descarga de google clasroom la carpeta "data_cinta_verde"

# %% [markdown]
# # 2. Importa la librería de pandas y asignale un alias

# %%
import pandas as pd

# %% [markdown]
# # 3. Guarda en un dataframe distinto cada uno de los archivos contenidos en la carpeta
#
# * bestsellers.csv
# * chess.csv
# * countries of the world.csv
# * movie_titles.tsv
#
# No olvides asignar los nombres de las columnas a movie_titles: ['id', 'title', 'year', 'imdb_rating', 'imdb_id','description']
#
# * weird_bands.csv

# %%
bestsellers = pd.read_csv("/home/tiamat/Desktop/Python_Dojo/ExamenCintaVerde/data_cinta_verde/bestsellers.csv")
bestsellers
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 bestsellers = pd.read_csv("/home/tiamat/Desktop/Python_Dojo/ExamenCintaVerde/data_cinta_verde/bestsellers.csv")
#       2 bestsellers
#
# ...

# %%
chess = pd.read_csv("/home/tiamat/Desktop/Python_Dojo/ExamenCintaVerde/data_cinta_verde/chess.csv")
chess.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 chess = pd.read_csv("/home/tiamat/Desktop/Python_Dojo/ExamenCintaVerde/data_cinta_verde/chess.csv")
#       2 chess.head()
#
# NameError: name 'pd' is not defined

# %%
countries = pd.read_csv("/home/tiamat/Desktop/Python_Dojo/ExamenCintaVerde/data_cinta_verde/countries of the world.csv")
countries
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
movies = pd.read_csv("/home/tiamat/Desktop/Python_Dojo/ExamenCintaVerde/data_cinta_verde/movie_titles.tsv", sep= "\t")
colnames = ['id', 'title', 'year', 'imdb_rating', 'imdb_id','description']
movies.columns = colnames
movies
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 movies = pd.read_csv("/home/tiamat/Desktop/Python_Dojo/ExamenCintaVerde/data_cinta_verde/movie_titles.tsv", sep= "\t")
#       2 colnames = ['id', 'title', 'year', 'imdb_rating', 'imdb_id','description']
#       3 movies.columns = colnames
#
# ...

# %%
bands = pd.read_csv("/home/tiamat/Desktop/Python_Dojo/ExamenCintaVerde/data_cinta_verde/weird_bands.csv", delimiter="#", index_col= 1)
bands
# Out:
#        Unnamed: 0                name        country    status  formed_in  \
# id
# 1               0          ('M') Inc.  United States   Unknown     2009.0
# 2               1               (sic)  United States  Split-up     1993.0
# 3               2           .F.O.A.D.         France    Active     2009.0
# 4               3            100 Suns  United States    Active     2004.0
# 5               4  12 Days of Anarchy  United States  Split-up     1998.0
# ...           ...                 ...            ...       ...        ...
# 37719       37718           Gladiator       Slovakia    Active     1988.0
# 37720       37719          Innersight        Hungary    Active     1997.0
# 37721       37720         Lunarsapian  International    Active     2008.0
# 37722       37721        Subconscious        Germany    Active     1990.0
# 37723       37722         Frozen Mist  United States    Active     2004.0
#
#                                                    genre  \
# id
# ...

# %% [markdown]
# # 4. Despliega las ultimas 15 entradas de los datos de paises del mundo (countries of the world)

# %%
countries.tail(15)
# Out:
#                    Country                               Region  Population  \
# 212  United Arab Emirates   NEAR EAST                               2602713
# 213        United Kingdom   WESTERN EUROPE                         60609153
# 214         United States   NORTHERN AMERICA                      298444215
# 215               Uruguay               LATIN AMER. & CARIB         3431932
# 216            Uzbekistan                  C.W. OF IND. STATES     27307134
# 217               Vanuatu   OCEANIA                                  208869
# 218             Venezuela               LATIN AMER. & CARIB        25730435
# 219               Vietnam         ASIA (EX. NEAR EAST)             84402966
# 220        Virgin Islands               LATIN AMER. & CARIB          108605
# 221     Wallis and Futuna   OCEANIA                                   16025
# 222             West Bank   NEAR EAST                               2460492
# ...

# %% [markdown]
# # 5. Almacena en una variable las columnas de los datos de bestsellers?

# %%
best_cols  = bestsellers.columns
best_cols
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %% [markdown]
# # 6. Cambia los nombres de las columnas de los datos de weird_bands por puras mayúsculas

# %%
col_bands = bands.columns
bands.columns = col_bands.str.upper()
bands
# Out:
#        UNNAMED: 0                NAME        COUNTRY    STATUS  FORMED_IN  \
# id
# 1               0          ('M') Inc.  United States   Unknown     2009.0
# 2               1               (sic)  United States  Split-up     1993.0
# 3               2           .F.O.A.D.         France    Active     2009.0
# 4               3            100 Suns  United States    Active     2004.0
# 5               4  12 Days of Anarchy  United States  Split-up     1998.0
# ...           ...                 ...            ...       ...        ...
# 37719       37718           Gladiator       Slovakia    Active     1988.0
# 37720       37719          Innersight        Hungary    Active     1997.0
# 37721       37720         Lunarsapian  International    Active     2008.0
# 37722       37721        Subconscious        Germany    Active     1990.0
# 37723       37722         Frozen Mist  United States    Active     2004.0
#
#                                                    GENRE  \
# id
# ...

# %%
#List comprehensions
bestsellers.columns = [x.upper() for x in bestellers.columns]

#ciclo por explicito
mayus = []
for col in bestsellers.columns:
    mayus.append(col.upper())
bestsellers.columns = mayus
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 bestsellers.columns = [x.upper() for x in bestellers.columns]
#
# NameError: name 'bestellers' is not defined

# %% [markdown]
# # 7. Responde las siguientes preguntas:
#
#  * ¿Cuántas entradas tienen los datos de movie_titles?
#  * ¿Qué datos tienen columnas vacías?

# %% [markdown]
# movie_titles tiene 616 filas y 6 columnas. Al desplegar movie_titles observamos que hay un dato faltante en toadas las columnas, ya que indica 615 non-null en todas.

# %%
movies.shape
# Out:
# (616, 6)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           616 non-null    object
#  1   title        615 non-null    object
#  2   year         615 non-null    object
#  3   imdb_rating  615 non-null    float64
#  4   imdb_id      615 non-null    float64
#  5   description  615 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 29.0+ KB

# %% [markdown]
# # 8. Calcula los siguientes datos:
# * El precio promedio de un libro bestseller
# * El numero promedio de jugadas/turnos de ajedrez
# * Mediana de millas cuadradas de los paises del mundo
# * Percentil 25% de imdb_rating de la base de datos de películas movie_titles
# * **Cuántas veces se repite el la descripción: ['drama'] en los datos de movie_titles

# %%
# El precio promedio de un libro bestseller
bestsellers['Price'].mean()
#El precio promedio de un bestseller es de $13.1
# Out:
# np.float64(13.1)

# %%
#El numero promedio de jugadas/turnos de ajedrez
chess['turns'].mean()
#El numero promedio de jugadas es de 60.46
# Out:
# np.float64(60.46599860404826)

# %%
#* Mediana de millas cuadradas de los paises del mundo

countries['Area (sq. mi.)'].mean()
#La mediana de area es 598226.9
# Out:
# np.float64(598226.9559471365)

# %%
#* Percentil 25% de imdb_rating de la base de datos de películas movie_titles

movies.describe()
#El percentil 25% es 6.20
# Out:
#        imdb_rating        imdb_id
# count   615.000000     615.000000
# mean      6.865528   49880.648780
# std       1.216452   61946.546168
# min       2.500000       9.000000
# 25%       6.200000    9968.000000
# 50%       7.000000   27112.000000
# 75%       7.800000   66999.000000
# max       9.300000  419312.000000

# %%
#**Cuántas veces se repite el la descripción: ['drama'] en los datos de movie_titles

movies.value_counts('description')

#Se repite 34 veces
# Out:
# description
# ['drama']                                   34
# ['comedy' 'romance']                        16
# ['comedy' 'drama' 'romance']                16
# ['crime' 'drama' 'thriller']                16
# ['drama' 'romance']                         15
#                                             ..
# ['horror' 'romance' 'thriller' 'comedy']     1
# ['horror' 'romance' 'thriller']              1
# ['horror' 'romance']                         1
# ['horror' 'thriller' 'mystery']              1
# []                                           1
# Name: count, Length: 289, dtype: int64

# %% [markdown]
# # 9. ¿Cuántos géneros (genre) musicales distintos hay descritos en los datos weird_bands?

# %%
genres = bands['GENRE'].unique()
genres
# Out:
# array(['Death Metal', 'Death metal', 'Death Metal| Melodic Death Metal',
#        ...,
#        'Black/Death/Doom Metal (early)| Drone/Dark Ambient/Noise (later)',
#        "Progressive Thrash/Death Metal (1992| 2002-present)| Crossover (1993-'97)",
#        'Gothic Metal (2004-2006)| Melodic Death/Gothic Metal (2006-2010)| Pagan Black Metal (2010-)'],
#       dtype=object)

# %%
genres.shape
#hay un total de 2563
#no lo hice con len porque me daba error y se me ocurrio esto
#NOTA: Pues es obvio que no hay 2563 tipos diferentes de generos musicales, porque en los datos vienen mas de uno por entrada, por lo que los 
#toma comodiferentes, then es probable que haya menos
# Out:
# (2563,)

# %% [markdown]
# # 10. Crea un DataFrame con las columnas 'genre' y 'active' de weird_bands

# %%
sub_bands = bands[['GENRE', 'ACTIVE']]
sub_bands
# Out:
#                                                    GENRE  \
# id
# 1                                            Death Metal
# 2                                            Death Metal
# 3                                            Death Metal
# 4                                            Death Metal
# 5                                            Death Metal
# ...                                                  ...
# 37719  Death/Thrash Metal (1988-93)| Grunge/Hard Rock...
# 37720  Post-Rock (early)| Progressive Death Metal (mi...
# 37721  Black/Death/Doom Metal (early)| Drone/Dark Amb...
# 37722  Progressive Thrash/Death Metal (1992| 2002-pre...
# 37723  Gothic Metal (2004-2006)| Melodic Death/Gothic...
#
#                                    ACTIVE
# id
# 1                                  2009-?
# 2                               1993-1996
# 3                            2009-present
# 4                            2004-present
# 5                               1998-2002
# ...

# %% [markdown]
# # 11. ¿Cuántas bandas activas hay de Death Metal activas desde el 2011-present?

# %%
sub_bands.value_counts('ACTIVE').head(20)
#Hay 983 bandas activas del 2011 al presente
# Out:
# ACTIVE
# 2006-present    1154
# 2009-present    1105
# 2010-present    1101
# 2008-present    1090
# 2007-present    1080
# 2005-present    1068
# 2011-present     983
# 2004-present     950
# 2012-present     943
# 2003-present     808
# 2013-present     791
# 2014-present     588
# 2002-present     582
# 2001-present     528
# 2003-?           501
# 2004-?           477
# 2005-?           463
# 2000-present     440
# 2002-?           406
# 1999-present     402
# Name: count, dtype: int64

# %% [markdown]
# # 12.¿Cuál es el mayor número de turnos en un juego de ajedrez de la base de datos chess.csv? (Punto extras si me das los ids de los 10 primeros juegos con mayor número de turnos)

# %%
chess['turns'].nlargest(10)
#El mayor numero de turnos fue de 349
# Out:
# 11554    349
# 13859    349
# 16386    259
# 4236     255
# 16645    226
# 15478    222
# 16943    222
# 6776     221
# 13230    218
# 13555    216
# Name: turns, dtype: int64

# %% [markdown]
# # 13. En una escala del 1 al 10, ¿qué tan dificil te pareció el examen? (1-lo más fácil del mundo / 10 - imposible)

# %% [markdown]
# Los ultimos dos fueron desafiantes porque no recordaba las funciones y metodos, de ahi en fuera me parecio un examen intermedio
#
# pongamosle un 6!

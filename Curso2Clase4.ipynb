# %% [markdown]
# # Seaborn
# es una libreria para la visualizacion de datoa

# %%
import seaborn as sns
import pandas as pd
# Out:
# /home/tiamat/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
#sns.histplot(cinta_verde['Minutes'], bins = 10)

# %% [markdown]
# # Metodo: plot() de pandas

# %%
houses = pd.read_csv("/home/tiamat/Desktop/Python_Dojo/data/kc_house_data.csv")
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses.plot()
#esto es cero informativo y no tiene sentido lol
#cuando no ponemos ningun argumento, usa line como plot
# Out:
# <Axes: >

# %%
houses['bedrooms'].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='bedrooms'>

# %%
houses['bedrooms'].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
titanic =  pd.read_csv("/home/tiamat/Desktop/Python_Dojo/data/titanic.csv")

# %%
titanic['sex'].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # eje x, eje y

# %%
bed_bath = houses[['bedrooms', 'bathrooms']]
bed_bath.head(2)
# Out:
#    bedrooms  bathrooms
# 0         3       1.00
# 1         3       2.25

# %%
bed_bath.plot(x = 'bedrooms', y = 'bathrooms')
# el default es line wakala
# Out:
# <Axes: xlabel='bedrooms'>

# %%
bed_bath.plot(x = 'bedrooms', y = 'bathrooms', kind = "scatter")
# Out:
# <Axes: xlabel='bedrooms', ylabel='bathrooms'>

# %% [markdown]
# # Haz un scatterplot de condition vs price

# %%
x = "price"
y = "sqft_lot15"
houses.plot(x = x, y = y, kind = "scatter")
# Out:
# <Axes: xlabel='price', ylabel='sqft_lot15'>

# %%
houses.price
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
bestsellers = pd.read_csv("/home/tiamat/Desktop/Python_Dojo/data/bestsellers.csv")
bestsellers.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %% [markdown]
#  # RETO
#
#  1) Cre una grafica de pay, con el numero de veces que cada genero (Titanic) aparece en el dataset
#  2) Crea una grafica de barras con los 10 autores mas prolificos y cuantos libros tiene cada uno
#  3) Crea un histograma que muestre la distribucion de reviews de usuarios (movies) imdb_rating

# %%
bestsellers.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
# 1) Cre una grafica de pay, con el numero de veces que cada genero (Titanic) aparece en el dataset

bestsellers.value_counts("Genre").plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
# 2) Crea una grafica de barras con los 10 autores mas prolificos y cuantos libros tiene cada ano
 
bestsellers.value_counts("Author").nlargest(10).plot(kind = "barh")
# Out:
# <Axes: ylabel='Author'>

# %%
# 3) Crea un histograma que muestre la distribucion de reviews de usuarios (User rating)

bestsellers['User Rating'].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

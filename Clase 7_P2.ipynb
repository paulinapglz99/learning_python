# %%
import pandas as pd

# %%
houses="C:\\Users\\User\\data\\kc_house_data.csv"
houses_df= pd.read_csv(houses)
houses_df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
netflix="C:\\Users\\User\\data\\netflix_titles.csv" 
netflix_tit=pd.read_csv(netflix, sep="|", index_col=0)
netflix_tit

# %%
book="C:\\Users\\User\\data\\bestsellers.csv" 
book_df=pd.read_csv(book)
book_df

# %%
titanic= "C:\\Users\\User\\data\\titanic.csv"
titanic_df= pd.read_csv(titanic) 
titanic_df

# %%
#lambda functions: son funciones que toman un argumento y le hacen una cosa, 
#pedacitos de código, sirve para cosas sencillas y rápidas
#pedazos de código que nos evitan definir una función 
#titanic_df.sort_values("name", key=lambda col:col.str.lower()) ejemplo
#str es un tipo de objeto: llamar al objeto str.lower/upper para poder aplicarlo

#titanic_df 
[]

#función: toma un argumento y te refresa un objeto

# %%
happy="C:\\Users\\User\\data\\world-happiness-report-2021.csv" 
happy_df=pd.read_csv(happy)
happy_df
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
happy_df.set_index("Country name", inplace=True)

# %%
happy_df
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
happy_df.loc["Rwanda"] #loc te permite seleccionar filas
#esto es una serie
# Out:
# Regional indicator                            Sub-Saharan Africa
# Ladder score                                               3.415
# Standard error of ladder score                             0.068
# upperwhisker                                               3.548
# lowerwhisker                                               3.282
# Logged GDP per capita                                      7.676
# Social support                                             0.552
# Healthy life expectancy                                     61.4
# Freedom to make life choices                               0.897
# Generosity                                                 0.061
# Perceptions of corruption                                  0.167
# Ladder score in Dystopia                                    2.43
# Explained by: Log GDP per capita                           0.364
# Explained by: Social support                               0.202
# ...

# %%
happy_df.loc[["Mexico", "Rwanda"]] #esto es un dataframe
# Out:
#                        Regional indicator  Ladder score  \
# Country name
# Mexico        Latin America and Caribbean         6.317
# Rwanda                 Sub-Saharan Africa         3.415
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Mexico                                 0.053         6.420         6.213
# Rwanda                                 0.068         3.548         3.282
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Mexico                        9.859           0.831                   68.597
# Rwanda                        7.676           0.552                   61.400
#
#               Freedom to make life choices  Generosity  \
# Country name
# Mexico                               0.862      -0.147
# Rwanda                               0.897       0.061
#
#               Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# ...

# %%
#otra forma de seleccionar filas de forma númerica se ocupa iloc
#columnas no requiero poner nada, para filas se ocupa loc
happy_df.iloc[[4, 10]] #iloc recibe números
# Out:
#                  Regional indicator  Ladder score  \
# Country name
# Netherlands          Western Europe         7.464
# Australia     North America and ANZ         7.183
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Netherlands                            0.027         7.518         7.410
# Australia                              0.041         7.265         7.102
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Netherlands                  10.932           0.942                     72.4
# Australia                    10.796           0.940                     73.9
#
#               Freedom to make life choices  Generosity  \
# Country name
# Netherlands                          0.913       0.175
# Australia                            0.914       0.159
#
#               Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# ...

# %%
happy_df.iloc[0:6] #como las listas, los puntitos se llaman slicing
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Finland          Western Europe         7.842                           0.032
# Denmark          Western Europe         7.620                           0.035
# Switzerland      Western Europe         7.571                           0.036
# Iceland          Western Europe         7.554                           0.059
# Netherlands      Western Europe         7.464                           0.027
# Norway           Western Europe         7.392                           0.035
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Finland              7.904         7.780                 10.775
# Denmark              7.687         7.552                 10.933
# Switzerland          7.643         7.500                 11.117
# Iceland              7.670         7.438                 10.878
# Netherlands          7.518         7.410                 10.932
# ...

# %%
happy_df.sort_index()
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Afghanistan                           South Asia         2.523
# Albania               Central and Eastern Europe         5.117
# Algeria             Middle East and North Africa         4.887
# Argentina            Latin America and Caribbean         5.929
# Armenia       Commonwealth of Independent States         5.283
# ...                                          ...           ...
# Venezuela            Latin America and Caribbean         4.892
# Vietnam                           Southeast Asia         5.411
# Yemen               Middle East and North Africa         3.658
# Zambia                        Sub-Saharan Africa         4.073
# Zimbabwe                      Sub-Saharan Africa         3.145
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# ...

# %%
happy_df.sort_index().loc["Mexico":"Morroco"] #tambien se puede hacer slicing a  nombres
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Mexico               Latin America and Caribbean         6.317
# Moldova       Commonwealth of Independent States         5.766
# Mongolia                               East Asia         5.677
# Montenegro            Central and Eastern Europe         5.581
# Morocco             Middle East and North Africa         4.918
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Mexico                                 0.053         6.420         6.213
# Moldova                                0.046         5.856         5.677
# Mongolia                               0.042         5.760         5.595
# Montenegro                             0.054         5.686         5.475
# Morocco                                0.060         5.036         4.800
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# ...

# %%
#happy_df.iloc[0:6] #iloc se fija en las posiciones, si cambio el dataframe, cambiara el iloc
#hard coden,
# se pueden seleccionar columnas y filas especifícas
#houses.loc[0:6, ["pice", "sqft_lot"]]

# %%
houses_df.loc[0:6, ["price", "sqft_lot"]]
# Out:
#        price  sqft_lot
# 0   221900.0      5650
# 1   538000.0      7242
# 2   180000.0     10000
# 3   604000.0      5000
# 4   510000.0      8080
# 5  1225000.0    101930
# 6   257500.0      6819

# %%
#otra forma de hacer lo mismo 
col=["price", "sqft_lot"]
houses_df.loc[0:6,][col]
# Out:
#        price  sqft_lot
# 0   221900.0      5650
# 1   538000.0      7242
# 2   180000.0     10000
# 3   604000.0      5000
# 4   510000.0      8080
# 5  1225000.0    101930
# 6   257500.0      6819

# %%
houses_df.loc[0:6, col] #otra forma de hacer lo mismo, son
# Out:
#        price  sqft_lot
# 0   221900.0      5650
# 1   538000.0      7242
# 2   180000.0     10000
# 3   604000.0      5000
# 4   510000.0      8080
# 5  1225000.0    101930
# 6   257500.0      6819

# %%
#si paso un argumento con multiples valores, es como lista, con corchetes o doble corchetes

# %%
#cuantas personas en el titatic tenían 18 años
#las 3 edades más comunes reportadas en el titanic crea una serie

# %%
titanic= "C:\\Users\\User\\data\\titanic.csv"
titanic_df= pd.read_csv(titanic) 
titanic_df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic_df["age"].value_counts().loc["18"]
# Out:
# 39

# %%
titanic_df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic_df["age"]
# Out:
# 0           29
# 1       0.9167
# 2            2
# 3           30
# 4           25
#          ...
# 1304      14.5
# 1305         ?
# 1306      26.5
# 1307        27
# 1308        29
# Name: age, Length: 1309, dtype: object

# %%
titanic_df.sort_values("age", ascending=False)
# Out:
#       pclass  survived                                             name  \
# 801        3         0                                 Flynn, Mr. James
# 491        2         0                              Malachard, Mr. Noel
# 900        3         0        Johnston, Master. William Arthur 'Willie'
# 483        2         1                       Leitch, Miss. Jessie Wills
# 1071       3         1  O'Brien, Mrs. Thomas (Johanna 'Hannah' Godfrey)
# ...      ...       ...                                              ...
# 657        3         1                           Baclini, Miss. Eugenie
# 427        2         1                        Hamalainen, Master. Viljo
# 1240       3         1                  Thomas, Master. Assad Alexander
# 747        3         0          Danbom, Master. Gilbert Sigvard Emanuel
# 763        3         1          Dean, Miss. Elizabeth Gladys 'Millvina'
#
#          sex     age  sibsp  parch      ticket     fare cabin embarked boat  \
# ...

# %%
titanic_df["age"].value_counts().sort_index().iloc[-3:]
# Out:
# age
# 80      1
# 9      10
# ?     263
# Name: count, dtype: int64

# %%
titanic_df["age"].value_counts()[:3]
# Out:
# age
# ?     263
# 24     47
# 22     43
# Name: count, dtype: int64

# %%
pokemon="C:\\Users\\User\\Pokemon.csv" 
pokemon_df=pd.read_csv(pokemon)
pokemon_df
# Out:
#      Num        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# ...

# %%
#has una grafica de los 
pokemon_df[["Name","Attack"]].value_counts().sort_index()#.plot(kind="bar")
# Out:
# Name        Attack
# Abra        20        1
# Aerodactyl  105       1
# Alakazam    50        1
# Arbok       85        1
# Arcanine    110       1
#                      ..
# Weepinbell  90        1
# Weezing     90        1
# Wigglytuff  70        1
# Zapdos      90        1
# Zubat       45        1
# Name: count, Length: 151, dtype: int64

# %%
pokemon_df[["Name","Attack"]].sort_index(ascending=True)[:10].plot(kind="bar", x="Name", y="Attack")
# Out:
# <Axes: xlabel='Name'>

# %%
pokemon_df[["Name","Attack"]]

# %%
pokemon_df.sort_values(["Attack", "Defense"], ascending=False, inplace=True)

# %%
pokemon_df
# Out:
#      Num       Name    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 148  149  Dragonite    Dragon  Flying    600   91     134       95      100
# 111  112     Rhydon    Ground    Rock    485  105     130      120       45
# 98    99    Kingler     Water     NaN    475   55     130      115       50
# 67    68    Machamp  Fighting     NaN    505   90     130       80       65
# 135  136    Flareon      Fire     NaN    525   65     130       60       95
# ..   ...        ...       ...     ...    ...  ...     ...      ...      ...
# 13    14     Kakuna       Bug  Poison    205   45      25       50       25
# 10    11    Metapod       Bug     NaN    205   50      20       55       25
# 62    63       Abra   Psychic     NaN    310   25      20       15      105
# 128  129   Magikarp     Water     NaN    200   20      10       55       15
# 112  113    Chansey    Normal     NaN    450  250       5        5       35
#
#      Sp. Def  Speed  Stage  Legendary
# ...

# %%
pokemon_df.value_counts("Type 2")
# Out:
# Type 2
# Flying      19
# Poison      19
# Ground       6
# Psychic      6
# Water        4
# Fairy        3
# Ice          3
# Grass        2
# Rock         2
# Steel        2
# Fighting     1
# Name: count, dtype: int64

# %%
pokemon_df[["Attack","Type 1"]][:30].value_counts()
# Out:
# Attack  Type 1
# 110     Normal      2
# 100     Fire        2
# 105     Fighting    2
# 95      Rock        1
# 130     Water       1
#         Ground      1
#         Fire        1
#         Fighting    1
# 125     Water       1
#         Bug         1
# 120     Rock        1
#         Fighting    1
# 115     Rock        1
# 110     Psychic     1
#         Bug         1
#         Fire        1
# 95      Water       1
# 105     Water       1
#         Rock        1
#         Poison      1
#         Grass       1
# 102     Poison      1
# 100     Psychic     1
#         Normal      1
#         Ground      1
#         Fighting    1
# 134     Dragon      1
# Name: count, dtype: int64

# %%
pokemon_df#.loc["Pikachu"]
# Out:
#      Num       Name    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 148  149  Dragonite    Dragon  Flying    600   91     134       95      100
# 111  112     Rhydon    Ground    Rock    485  105     130      120       45
# 98    99    Kingler     Water     NaN    475   55     130      115       50
# 67    68    Machamp  Fighting     NaN    505   90     130       80       65
# 135  136    Flareon      Fire     NaN    525   65     130       60       95
# ..   ...        ...       ...     ...    ...  ...     ...      ...      ...
# 13    14     Kakuna       Bug  Poison    205   45      25       50       25
# 10    11    Metapod       Bug     NaN    205   50      20       55       25
# 62    63       Abra   Psychic     NaN    310   25      20       15      105
# 128  129   Magikarp     Water     NaN    200   20      10       55       15
# 112  113    Chansey    Normal     NaN    450  250       5        5       35
#
#      Sp. Def  Speed  Stage  Legendary
# ...

# %%
pokemon_df.set_index("Name")
# Out:
#            Num    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Dragonite  149    Dragon  Flying    600   91     134       95      100
# Rhydon     112    Ground    Rock    485  105     130      120       45
# Kingler     99     Water     NaN    475   55     130      115       50
# Machamp     68  Fighting     NaN    505   90     130       80       65
# Flareon    136      Fire     NaN    525   65     130       60       95
# ...        ...       ...     ...    ...  ...     ...      ...      ...
# Kakuna      14       Bug  Poison    205   45      25       50       25
# Metapod     11       Bug     NaN    205   50      20       55       25
# Abra        63   Psychic     NaN    310   25      20       15      105
# Magikarp   129     Water     NaN    200   20      10       55       15
# Chansey    113    Normal     NaN    450  250       5        5       35
#
#            Sp. Def  Speed  Stage  Legendary
# Name
# Dragonite      100     80      3      False
# ...

# %%
pokemon_df.sort_values("Name", key=lambda col:col.str.lower())
# Out:
#      Num        Name    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 62    63        Abra   Psychic     NaN    310   25      20       15      105
# 141  142  Aerodactyl      Rock  Flying    515   80     105       65       60
# 64    65    Alakazam   Psychic     NaN    500   55      50       45      135
# 23    24       Arbok    Poison     NaN    438   60      85       69       65
# 58    59    Arcanine      Fire     NaN    555   90     110       80      100
# ..   ...         ...       ...     ...    ...  ...     ...      ...      ...
# 69    70  Weepinbell     Grass  Poison    390   65      90       50       85
# 109  110     Weezing    Poison     NaN    490   65      90      120       85
# 39    40  Wigglytuff    Normal   Fairy    435  140      70       45       85
# 144  145      Zapdos  Electric  Flying    580   90      90       85      125
# 40    41       Zubat    Poison  Flying    245   40      45       35       30
#
#      Sp. Def  Speed  Stage  Legendary
# ...

# %%
equipo_original=pokemon_df.set_index("Name").sort_values("Name", key=lambda col:col.str.lower()).loc[["Bulbasaur","Caterpie", "Charmander", "Pidgeotto", "Pikachu", "Squirtle"]]

# %%
equipo_original
# Out:
#             Num    Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur     1     Grass  Poison    318  45      49       49       65
# Caterpie     10       Bug     NaN    195  45      30       35       20
# Charmander    4      Fire     NaN    309  39      52       43       60
# Pidgeotto    17    Normal  Flying    349  63      60       55       50
# Pikachu      25  Electric     NaN    320  35      55       40       50
# Squirtle      7     Water     NaN    314  44      48       65       50
#
#             Sp. Def  Speed  Stage  Legendary
# Name
# Bulbasaur        65     45      1      False
# Caterpie         20     45      1      False
# Charmander       50     65      1      False
# Pidgeotto        50     71      2      False
# Pikachu          50     90      1      False
# Squirtle         64     43      1      False

# %%
equipo_original["Attack"].plot(kind="bar")
# Out:
# <Axes: xlabel='Name'>
